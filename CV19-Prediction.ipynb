# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('country_vaccinations.csv')

# %%
df.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.isnull().sum()
# Out:
# country                                   0
# iso_code                                304
# date                                      0
# total_vaccinations                     1519
# people_vaccinated                      1952
# people_fully_vaccinated                2773
# daily_vaccinations_raw                 1968
# daily_vaccinations                      154
# total_vaccinations_per_hundred         1519
# people_vaccinated_per_hundred          1952
# people_fully_vaccinated_per_hundred    2773
# daily_vaccinations_per_million          154
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %% [markdown]
# ### Dropping the rows with null values

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index    country iso_code        date  total_vaccinations  \
# 0     39    Albania      ALB  2021-02-18              3049.0
# 1    134  Argentina      ARG  2021-01-21            265724.0
# 2    135  Argentina      ARG  2021-01-22            279602.0
# 3    136  Argentina      ARG  2021-01-23            288064.0
# 4    137  Argentina      ARG  2021-01-24            292023.0
#
#    people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0             2438.0                    611.0                  1348.0
# 1           249372.0                  16352.0                 17791.0
# 2           254456.0                  25146.0                 13878.0
# 3           258876.0                  29188.0                  8462.0
# 4           260036.0                  31987.0                  3959.0
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0               254.0                            0.11
# 1             11704.0                            0.59
# ...

# %%
df['Month'] = pd.to_datetime(df['date'], format="%Y/%m/%d").dt.month
df['Year'] = pd.to_datetime(df['date'], format="%Y/%m/%d").dt.year
df['Day'] = pd.to_datetime(df['date'], format="%Y/%m/%d").dt.day

# %%
df.drop(['date', 'source_name', 'source_website'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    index    country iso_code  total_vaccinations  people_vaccinated  \
# 0     39    Albania      ALB              3049.0             2438.0
# 1    134  Argentina      ARG            265724.0           249372.0
# 2    135  Argentina      ARG            279602.0           254456.0
# 3    136  Argentina      ARG            288064.0           258876.0
# 4    137  Argentina      ARG            292023.0           260036.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                    611.0                  1348.0               254.0
# 1                  16352.0                 17791.0             11704.0
# 2                  25146.0                 13878.0             11263.0
# 3                  29188.0                  8462.0             11124.0
# 4                  31987.0                  3959.0             10342.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df['iso_code'].value_counts()
# Out:
# ISR    55
# GBR    47
# CHL    46
# DEU    44
# DNK    43
# ROU    42
# CZE    42
# ITA    42
# BGR    41
# MEX    41
# HUN    40
# SVK    40
# BEL    40
# SVN    40
# NOR    40
# USA    39
# AUT    39
# PRT    37
# LTU    36
# MLT    34
# POL    33
# GRC    33
# LVA    33
# ARG    32
# FRA    32
# FIN    28
# IMN    27
# GIB    27
# EST    27
# IDN    24
# ESP    24
# OMN    23
# BRA    22
# LUX    19
# IRL    17
# TUR    16
# IND    13
# CHE    11
# ZAF     9
# SYC     8
# MAR     7
# ISL     6
# SRB     4
# SWE     4
# CYM     3
# HRV     2
# ARE     2
# FRO     1
# ALB     1
# Name: iso_code, dtype: int64

# %%
thisdict = {'ISR' : 1,
            'GBR' : 2,
            'CHL' : 3,
            'DEU' : 4,
            'DNK' : 5,
            'ROU' : 6,
            'ITA' : 7,
            'CZE' : 8,
            'MEX' : 9,
            'BGR' : 10,
            'HUN' : 11,
            'SVN' : 12,
            'SVK' : 13,
            'BEL' : 14,
            'NOR' : 15,
            'USA' : 16,
            'AUT' : 17,
            'PRT' : 18,
            'LTU' : 19,
            'MLT' : 20,
            'GRC' : 21,
            'LVA' : 22,
            'POL' : 23,
            'FRA' : 24,
            'ARG' : 25,
            'FIN' : 26,
            'IMN' : 27,
            'GIB' : 28,
            'EST' : 29,
            'IDN' : 30,
            'ESP' : 31,
            'OMN' : 32,
            'BRA' : 33,
            'LUX' : 34,
            'IRL' : 35,
            'TUR' : 36,
            'IND' : 37,
            'CHE' : 38,
            'ZAF' : 39,
            'SYC' : 40,
            'MAR' : 41,
            'ISL' : 42,
            'SWE' : 43,
            'SRB' : 44,
            'CYM' : 45,
            'ARE' : 46,
            'HRV' : 47,
            'FRO' : 48,
            'ALB' : 49}

# %%
df['iso_code']= df['iso_code'].replace(thisdict)

# %%
df.drop('country', axis=1, inplace=True)

# %%
df.head()
# Out:
#    index  iso_code  total_vaccinations  people_vaccinated  \
# 0     39        49              3049.0             2438.0
# 1    134        25            265724.0           249372.0
# 2    135        25            279602.0           254456.0
# 3    136        25            288064.0           258876.0
# 4    137        25            292023.0           260036.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                    611.0                  1348.0               254.0
# 1                  16352.0                 17791.0             11704.0
# 2                  25146.0                 13878.0             11263.0
# 3                  29188.0                  8462.0             11124.0
# 4                  31987.0                  3959.0             10342.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.11                           0.08
# ...

# %%
df.drop('vaccines', axis=1, inplace=True)

# %%
df.drop('index', axis=1, inplace=True)

# %%
df.head()
# Out:
#    iso_code  total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0        49              3049.0             2438.0                    611.0
# 1        25            265724.0           249372.0                  16352.0
# 2        25            279602.0           254456.0                  25146.0
# 3        25            288064.0           258876.0                  29188.0
# 4        25            292023.0           260036.0                  31987.0
#
#    daily_vaccinations_raw  daily_vaccinations  total_vaccinations_per_hundred  \
# 0                  1348.0               254.0                            0.11
# 1                 17791.0             11704.0                            0.59
# 2                 13878.0             11263.0                            0.62
# 3                  8462.0             11124.0                            0.64
# 4                  3959.0             10342.0                            0.65
#
# ...

# %% [markdown]
# ### We have completed data preprocessing. We will now do model training and testing.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %% [markdown]
# ### Now, we will see total vaccinations in India, by 15th March, 2021.

# %%
data = {'iso_code' : 37.00,
        'people_vaccinated' : 8044786.00,
        'people_fully_vaccinated' : 7668.00,
        'daily_vaccinations_raw' : 84807.00,
        'daily_vaccinations' : 325305.00,
        'total_vaccinations_per_hundred' : 0.58,
        'people_vaccinated_per_hundred' : 0.58,
        'people_fully_vaccinated_per_hundred' : 0.00,
        'daily_vaccinations_per_million' : 236.00,
        'Month' : 3.00,
        'Year' : 2021.00,
        'Day' : 13.00}

# %%
india_data = pd.Series(data=data)

# %%
india_data
# Out:
# iso_code                                    37.00
# people_vaccinated                      8044786.00
# people_fully_vaccinated                   7668.00
# daily_vaccinations_raw                   84807.00
# daily_vaccinations                      325305.00
# total_vaccinations_per_hundred               0.58
# people_vaccinated_per_hundred                0.58
# people_fully_vaccinated_per_hundred          0.00
# daily_vaccinations_per_million             236.00
# Month                                        3.00
# Year                                      2021.00
# Day                                         13.00
# dtype: float64

# %%
totalVaccinationInIndia = lm.predict([india_data])

# %%
totalVaccinationInIndia
# Out:
# array([8059726.47285264])

# %% [markdown]
# ## Here, we can see that total vaccinations in India by 15th March 2021 is around 8059726.47285264.
